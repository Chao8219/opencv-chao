# %%
from matplotlib import pyplot
# %matplotlib inline
import sys
ros_path = '/opt/ros/kinetic/lib/python2.7/dist-packages'
if ros_path in sys.path:
    sys.path.remove(ros_path)
    print('ROS path removed temporarily.')
else:
    print('No ROS path detected.')
import cv2
print(cv2.__file__)
print(cv2.__version__)
# Out:
# ROS path removed temporarily.
# /home/zichao/anaconda3/envs/opencv/lib/python3.6/site-packages/cv2.cpython-36m-x86_64-linux-gnu.so
# 4.1.1

# %% [markdown]
# # About
#
# This notebook is to try to get access of a USB camera through opencv.
#
# The current development environment is **Ubuntu 16.04** with **conda env**.
# All the modules are installed through **conda-forge** channel.
# One should be aware of the confliction between modules in different channel.
# So one should either stick with **main** or **conda-forge** channel for all modules in this conda env.
#
# The suggested steps to make it good to work is showing below:
#
# 1. create a conda env: `conda create -n your_env_name python=3.6`
# 2. activate the env: `conda activate your_env_name`
# 3. install modules: `conda install -c conda-forge opencv numpy matplotlib jupyter pylint`

# %% [markdown]
# # 1. Demo Test
#
# The following script is from [OpenCV Tutorial](https://docs.opencv.org/master/dd/d43/tutorial_py_video_display.html).
# It should be working for both OpenCV 3.X and 4.X (and maybe 2.X) versions.

# %%
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("Cannot open camera")
    raise ValueError('Hold on')
while True:
    # Capture frame-by-frame
    ret, frame = cap.read()
    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break
    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Display the resulting frame
    cv2.imshow('frame', gray)
    # Press Q on keyboard to exit the while loop
    if cv2.waitKey(1) == ord('q'):
        break
    if cv2.waitKey(2) == ord('s'):
        frame_saved = frame
        print('frame saved.')
# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# frame saved.
# frame saved.

# %%
pyplot.imshow(frame_saved, cmap='gray')
pyplot.show()
